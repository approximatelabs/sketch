# %%
import pandas as pd
import random

local_df = pd.DataFrame(
    {'i': range(120),
     'age': [random.randint(20,80) for _ in range(120)]
    }
)

# %%
local_df.head()
# Out:
#    i  age
# 0  0   50
# 1  1   80
# 2  2   69
# 3  3   32
# 4  4   57

# %%
from sketch import Portfolio
test = Portfolio.from_dataframe(local_df)

# %%
test.find_joinables(apiKey="8f79be2b6d0d47ccb8192e46f38c80ce")
# Out:
# 0.9297  i -- SQLITE:[../datasets/food-trucks.db] TABLE:[Applicant] COL:[id]
# 0.3828  age -- SQLITE:[../datasets/food-trucks.db] TABLE:[Applicant] COL:[id]
# 0.3047  i -- SQLITE:[../datasets/food-trucks.db] TABLE:[block] COL:[id]
# 0.2734  i -- SQLITE:[../datasets/food-trucks.db] TABLE:[Mobile_Food_Facility_Permit_fts_segments] COL:[blockid]
# 0.1484  i -- SQLITE:[../datasets/food-trucks.db] TABLE:[Mobile_Food_Facility_Permit_fts_docsize] COL:[docid]

# %%
test.find_joinables_html(apiKey='8f79be2b6d0d47ccb8192e46f38c80ce')
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" type="text/css" href="http://localhost:8000/static/output.css">
#     <script src="https://cdn.jsdelivr.net/npm/vega@5.22.1/build/vega.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/vega-lite@5.4.0/build/vega-lite.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/vega-embed@6.21.0/build/vega-embed.min.js"></script>
#     <link id="favicon" rel="icon" type="image/x-icon" href="static/favicon.ico">
#     <title> Landing Page! </title>
# </head>
#
# <body>
#     <div class="flex flex-col h-screen">
#
#
# <div class="flex justify-center items-center">
#     <ul class="grow">
#
#         <li class="p-2">
#             <!-- Flexbox for card, full width, rounded with shadow -->
# <div class="flex flex-row items-baseline shadow-lg justify-center bg-slate-50">
#     <div class="grow flex flex-col px-4">
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Source
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 ../datasets/food-trucks.db
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Relation
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 Applicant
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Reference
#             </span>
#             <a class="text-xl font-bold underline"
#                 href="/reference/">
#                 id
#             </a>
#         </div>
#     </div>
#     <div class="flex flex-col items-end px-4">
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Est #Uniques:
#             </span>
#             137
#         </p>
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Rows:
#             </span>
#             131
#         </p>
#     </div>
# </div>
#         </li>
#
#         <li class="p-2">
#             <!-- Flexbox for card, full width, rounded with shadow -->
# <div class="flex flex-row items-baseline shadow-lg justify-center bg-slate-50">
#     <div class="grow flex flex-col px-4">
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Source
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 ../datasets/food-trucks.db
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Relation
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 block
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Reference
#             </span>
#             <a class="text-xl font-bold underline"
#                 href="/reference/">
#                 id
#             </a>
#         </div>
#     </div>
#     <div class="flex flex-col items-end px-4">
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Est #Uniques:
#             </span>
#             462
#         </p>
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Rows:
#             </span>
#             414
#         </p>
#     </div>
# </div>
#         </li>
#
#         <li class="p-2">
#             <!-- Flexbox for card, full width, rounded with shadow -->
# <div class="flex flex-row items-baseline shadow-lg justify-center bg-slate-50">
#     <div class="grow flex flex-col px-4">
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Source
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 ../datasets/food-trucks.db
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Relation
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 Mobile_Food_Facility_Permit_fts_segments
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Reference
#             </span>
#             <a class="text-xl font-bold underline"
#                 href="/reference/">
#                 blockid
#             </a>
#         </div>
#     </div>
#     <div class="flex flex-col items-end px-4">
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Est #Uniques:
#             </span>
#             29
#         </p>
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Rows:
#             </span>
#             28
#         </p>
#     </div>
# </div>
#         </li>
#
#         <li class="p-2">
#             <!-- Flexbox for card, full width, rounded with shadow -->
# <div class="flex flex-row items-baseline shadow-lg justify-center bg-slate-50">
#     <div class="grow flex flex-col px-4">
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Source
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 ../datasets/food-trucks.db
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Relation
#             </span>
#             <a class="text-l font-bold" href="/source/">
#                 Mobile_Food_Facility_Permit_fts_docsize
#             </a>
#         </div>
#         <div class="">
#             <span class="text-sm text-bold text-blue-500">
#                 Reference
#             </span>
#             <a class="text-xl font-bold underline"
#                 href="/reference/">
#                 docid
#             </a>
#         </div>
#     </div>
#     <div class="flex flex-col items-end px-4">
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Est #Uniques:
#             </span>
#             735
#         </p>
#         <p class="text-xl">
#             <span class="text-sm text-cyan-500">
#                 Rows:
#             </span>
#             673
#         </p>
#     </div>
# </div>
#         </li>
#
#     </ul>
# </div>
#
#
#     </div>
#
#
#     <!-- Hot reload script -->
#     <script>const ws = new WebSocket("ws://localhost:8000/hot-reload");
# ws.onmessage = () => window.location.reload();
# </script>
#
# </body>
#
# </html>
